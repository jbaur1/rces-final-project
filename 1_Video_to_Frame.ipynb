# %% [markdown]
# # Used to distill a Video into 1 Second Frames

# %%
import matplotlib 
matplotlib.use("Agg") 
import matplotlib.pyplot as plt
import sys
import argparse
import cv2

# %% [markdown]
# ### Extracts Images from Video Data

# %%
def extractImages(pathIn, pathOut):
    count = 0
    vidcap = cv2.VideoCapture(pathIn)
    success,image = vidcap.read()
    success = True
    while success:
        vidcap.set(cv2.CAP_PROP_POS_MSEC,(count*1000))    # added this line 
        success,image = vidcap.read()
        print ('Read a new frame', "%03d" % count, success)
        cv2.imwrite( pathIn + "_%03d.jpg" % count, image)    # save frame as JPEG file, or can change to .TIF
        count = count + 1

# %% [markdown]
# ### Using the command above this extracts frames and names them , input video, (input Video must be in same dirctory as this code)

# %%
extractImages('DJI_0003_20180726_1113-Vpt6_Trim.MOV', '')
# Out:
# Read a new frame 000 True
# Read a new frame 001 True
# Read a new frame 002 True
# Read a new frame 003 True
# Read a new frame 004 True
# Read a new frame 005 True
# Read a new frame 006 True
# Read a new frame 007 True
# Read a new frame 008 True
# Read a new frame 009 True
# Read a new frame 010 True
# Read a new frame 011 True
# Read a new frame 012 True
# Read a new frame 013 True
# Read a new frame 014 True
# Read a new frame 015 True
# Read a new frame 016 True
# Read a new frame 017 True
# Read a new frame 018 True
# Read a new frame 019 True
# Read a new frame 020 True
# Read a new frame 021 True
# Read a new frame 022 True
# Read a new frame 023 True
# Read a new frame 024 True
# Read a new frame 025 True
# Read a new frame 026 True
# Read a new frame 027 True
# Read a new frame 028 True
# Read a new frame 029 True
# Read a new frame 030 True
# Read a new frame 031 True
# Read a new frame 032 True
# Read a new frame 033 True
# Read a new frame 034 True
# ...
